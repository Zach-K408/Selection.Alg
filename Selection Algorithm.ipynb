# %%
##Player Selection Algorithm 

#Methodology

#Import Data:
    #(Tim's app)
    #Import todays player picks 1, 2, & 3
    #Import todays competing teams 

    #(NHL app)    
    #Per individual player pick -> attribute ['goals', 'goals in last 5 games']
    #Per individual team -> attribute ['pts in standings','goal differential','W/L ratio in last five games']
    
#Store Data:
    #Player_Score : has score attributes ['goals', 'goals in last 5 games']
    #Player_Id : has id attributes ['team name']
    
    #Team_Score : has score attributes ['pts in standings','goal differential','W/L ratio in last five games']
    #Team_Id : has id attributes ['player name']

#Compare Data:
    #Rank each player against the population of the current pick category -> Append score to each player ->
    #loop all pick categories to obtain scores: 1.1, 1.2 & 1.3
    #Rank each game based on potential for highest goal differential -> 
    #Append score to favoured team and zero to unfavoured team (score 2)
    #Pair each player with corresponding team
    #Weight score 1 and 2 -> Sum both weighted scores associated with each pair -> 
    #Rank total score from each pair -> Select the player associated with the highest total score
